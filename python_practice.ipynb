# %% [markdown]
# **这是加粗的文字**
# *这是倾斜的文字*
# ***这是斜体加粗的文字***
# ~~这是加删除线的文字~~

# %% [markdown]
# # 1 引言

# %%
# 0000

# %% [markdown]
# # 2 变量和简单的数据类型

# %%
# 变量为“标签”，赋值后永远等于最新的赋值结果
message = "hello world"
print (message)


# 字符串(string)及修改
## 首字母大写
name = "my name is tom"
print (name.title())
## 全部大写
print (name.upper())
name = "My Name Is Tom"
## 全部小写
print (name.lower())

#合并字符串
first_name = "tom"
last_name = "ada"
# Out:
# hello world
# My Name Is Tom
# MY NAME IS TOM
# my name is tom
